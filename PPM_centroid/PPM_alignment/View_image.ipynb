# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import imageio

# %%
ls
# Out:
# IM1K1.png  IM2K3.png  IM3L0.png  im4l0_001.tiff  IM6K2\.png
# IM1K2.png  IM2L1.png  IM3L1.png  IM4L1.png       IM6K4.png
# IM1K3.png  IM3K3.png  IM4K2.png  IM5K2.png       IM7K2.png
# Im2K1.png  IM3K4.png  IM4K4.png  IM5K4.png       Untitled.ipynb

# %%
im = imageio.imread('im4l0_001.tiff')

# %%
plt.figure()
plt.imshow(im)
# Out:
# <img src="data:image/png;base64,..." width="640">
