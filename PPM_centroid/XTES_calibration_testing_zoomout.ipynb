# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from analysis_tools import XTESAlign
import imageio

# %%
im0 = imageio.imread("XTES_pattern_zoom_out.png")[:, :, 3]

plt.figure()
plt.imshow(im0)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
align = XTESAlign()

# %%
im = imageio.imread('PPM_alignment/im4l0_001.tiff')
im = im-np.min(im)

output = align.check_alignment(im)
print(output)
# Out:
# {'shifts': array([[67., 67., 67., ..., 67., 67., 67.],
#        [67., 67., 67., ..., 67., 67., 67.],
#        [67., 67., 67., ..., 67., 67., 67.],
#        ...,
#        [67., 67., 67., ..., 67., 67., 67.],
#        [67., 67., 67., ..., 67., 67., 67.],
#        [67., 67., 67., ..., 67., 67., 67.]]), 'scale': 1.9893892292229045, 'contrast': 0, 'rotation': 0.0, 'translation': array([30,  2])}

# %%
plt.figure()
plt.imshow(output['shifts'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
2e-3/400/output['scale']
# Out:
# 2.5133342065761064e-06

# %%
2e-3/500/output['scale']
# Out:
# 2.528794178983218e-06

# %%
plt.figure()
plt.imshow(im)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
2e-3/(912-115)
# Out:
# 2.5094102885821832e-06

# %%
(2.509-2.529)/2.509
# Out:
# -0.00797130330809088

# %%
1024*2.5
# Out:
# 2560.0

# %%
2e-3/(1498-499)/output['scale']
# Out:
# 2.5138839982322776e-06
